# %%
import pandas as pd

df = pd.read_excel('oasis_longitudinal_demographics.xlsx')
df.head(-1)
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0004  OAS2_0004_MR1  Nondemented      1         0   F    R   88
# 3    OAS2_0004  OAS2_0004_MR2  Nondemented      2       538   F    R   90
# 4    OAS2_0005  OAS2_0005_MR1  Nondemented      1         0   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 367  OAS2_0144  OAS2_0144_MR2    Converted      2       683   M    R   79
# 368  OAS2_0145  OAS2_0145_MR1    Converted      1         0   F    R   68
# 369  OAS2_0145  OAS2_0145_MR2    Converted      2      1707   F    R   73
# 370  OAS2_0176  OAS2_0176_MR1    Converted      1         0   M    R   84
# 371  OAS2_0176  OAS2_0176_MR2    Converted      2       774   M    R   87
#
#      EDUC  SES  MMSE  CDR         eTIV      nWBV       ASF
# 0      14  2.0  27.0  0.0  1986.550000  0.696106  0.883440
# 1      14  2.0  30.0  0.0  2004.479526  0.681062  0.875539
# 2      18  3.0  28.0  0.0  1215.330000  0.709512  1.444060
# 3      18  3.0  27.0  0.0  1200.100000  0.718214  1.462380
# 4      12  4.0  28.0  0.0  1688.580000  0.711502  1.039330
# ..    ...  ...   ...  ...          ...       ...       ...
# 367    16  1.0  30.0  0.5  1721.810000  0.707768  1.019270
# 368    16  3.0  30.0  0.0  1298.110000  0.798981  1.351970
# 369    16  3.0  29.0  0.5  1286.991849  0.770652  1.363645
# 370    16  2.0  30.0  0.0  1404.070000  0.710135  1.249940
# 371    16  2.0  30.0  0.0  1397.960000  0.696374  1.255400
#
# [372 rows x 15 columns]

# %%
import pandas as pd

df = pd.read_excel('oasis_longitudinal_demographics_edited.xlsx', sheet_name = 'Total data')
df.head(150)
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 1    OAS2_0077  OAS2_0077_MR2  Nondemented      2      1393   M    R   73
# 2    OAS2_0171  OAS2_0171_MR3  Nondemented      3      1695   M    R   81
# 3    OAS2_0161  OAS2_0161_MR3  Nondemented      3      1033   M    R   80
# 4    OAS2_0117  OAS2_0117_MR4  Nondemented      4      1927   M    R   78
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 145  OAS2_0092  OAS2_0092_MR2    Converted      2       706   F    R   84
# 146  OAS2_0131  OAS2_0131_MR2    Converted      2       679   F    R   67
# 147  OAS2_0041  OAS2_0041_MR3    Converted      3      1331   F    R   75
# 148  OAS2_0145  OAS2_0145_MR2    Converted      2      1707   F    R   73
# 149  OAS2_0054  OAS2_0054_MR2    Converted      2       846   F    R   87
#
#      EDUC  SES  MMSE  CDR         eTIV      nWBV       ASF
# 0      14  2.0  30.0  0.0  2004.479526  0.681062  0.875539
# 1      16  2.0  29.0  0.0  1930.580505  0.721600  0.909053
# 2      16  3.0  30.0  0.0  1836.152429  0.743938  0.955803
# 3      16  1.0  29.0  0.0  1829.729826  0.723766  0.959158
# 4      20  2.0  29.0  0.0  1825.538820  0.733744  0.961360
# ..    ...  ...   ...  ...          ...       ...       ...
# 145    12  2.0  27.0  0.5  1389.820000  0.727641  1.262750
# 146    12  2.0  25.0  0.0  1331.136768  0.760526  1.318422
# 147    16  1.0  28.0  0.5  1314.194272  0.760334  1.335419
# 148    16  3.0  29.0  0.5  1286.991849  0.770652  1.363645
# 149    18  1.0  24.0  0.5  1275.180000  0.682665  1.376270
#
# [150 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import openpyxl
import pandas as pd
import statistics

# can also index sheet by name or fetch all sheets
df = pd.read_excel(
    'oasis_longitudinal_demographics_edited.xlsx', sheet_name='Total data')
list = df['eTIV'].tolist()
list = np.around(list)
list = np.asarray(list )
# np.around(list)
#list = list.tolist()
# print(list)

# can also index sheet by name or fetch all sheets
df = pd.read_excel(
   'oasis_longitudinal_demographics_edited.xlsx', sheet_name='Nondemented data')
list1 = df['eTIV'].tolist()
#list1 = np.around(list1)


# can also index sheet by name or fetch all sheets
df = pd.read_excel(
    'oasis_longitudinal_demographics_edited.xlsx', sheet_name='Demented data')
list2 = df['eTIV'].tolist()
#list2 = np.around(list2)



# can also index sheet by name or fetch all sheets
df = pd.read_excel(
   'oasis_longitudinal_demographics_edited.xlsx', sheet_name='Converted data')
list3 = df['eTIV'].tolist()
#list3 = np.around(list3)



# calculating mean, mode and median for seperated data
mean = np.mean(list)
mode = statistics.mode(list)
median = np.median(list)

mean1 = np.mean(list1)
mode1 = statistics.mode(list1)
median1 = np.median(list1)
# print(mode1)

mean2 = np.mean(list2)
mode2 = statistics.mode(list2)
median2 = np.median(list2)
# print(mode2)

mean3 = np.mean(list3)
mode3 = statistics.mode(list3)
median3 = np.median(list3)
# print(median3)

df1 = pd.read_excel('oasis_longitudinal_demographics_edited.xlsx' ,sheet_name='Total data' )
plt.figure()
sns.histplot(df1, hue='Group', x='eTIV', stat='density', bins=len(list)//5, cumulative=False,
             common_norm=False, element='bars', kde=True, kde_kws=None,  palette=None, color=None)
plt.axvline(x=mean, color='red')
plt.axvline(x=mode, color='green')
plt.axvline(x=median, color='black')

plt.show()


fig = plt.figure(figsize=(10, 10))

plt.subplot(3, 2, 1)
sns.histplot(list1, hue=None, stat='density', bins=len(list1)//5, cumulative=False,
             common_norm=False, element='bars', kde=True, kde_kws=None,  palette=None, color=None)
plt.xlabel("nondemented")
#plt.ylabel("Calorie Burnage")
plt.axvline(x=mean1, color='red', label='mean')
plt.axvline(x=mode1, color='green', label='mode')
plt.axvline(x=median1, color='black', label='median')
plt.legend()

plt.subplot(3, 2, 2)
sns.kdeplot(list1)
plt.xlabel("nondemented")
plt.axvline(x=mean1, color='red', label='mean')
plt.axvline(x=mode1, color='green', label='mode')
plt.axvline(x=median1, color='black', label='median')
plt.legend()

plt.subplot(3, 2, 3)
sns.histplot(list2, hue=None, stat='density', bins=len(list2)//5, cumulative=False,
             common_norm=False, element='bars', kde=True, kde_kws=None,  palette=None, color=None)
plt.xlabel("demented")
plt.axvline(x=mean2, color='red', label='mean')
plt.axvline(x=mode2, color='green', label='mode')
plt.axvline(x=median2, color='black', label='median')
plt.legend()

plt.subplot(3, 2, 4)
sns.kdeplot(list2)
plt.xlabel("demented")
plt.axvline(x=mean2, color='red', label='mean')
plt.axvline(x=mode2, color='green', label='mode')
plt.axvline(x=median2, color='black', label='median')
plt.legend()

plt.subplot(3, 2, 5)
sns.histplot(list3, hue=None, stat='density', bins=len(list1)//5, cumulative=False,
             common_norm=False, element='bars', kde=True, kde_kws=None,  palette=None, color=None)
plt.xlabel("converted")
plt.axvline(x=mean3, color='red', label='mean')
plt.axvline(x=mode3, color='green', label='mode')
plt.axvline(x=median3, linestyle=':', color='black', label='median')
plt.legend()

plt.subplot(3, 2, 6)
sns.kdeplot(list3)
plt.xlabel("converted")
plt.axvline(x=mean3, color='red', label='mean')
plt.axvline(x=mode3, color='green', label='mode')
plt.axvline(x=median3, linestyle=':', color='black', label='median')
plt.legend()

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()

# show plot
plt.show()

# %%
# Importing library
from scipy.stats import skew

# Creating a dataset

# Calculate the skewness
print('calculate with scipy\n')
print('skewness of total data: ', skew(list, axis=0, bias=True))
print('skewness of nondemented data: ', skew(list1, axis=0, bias=True))
print('skewness of demented data: ', skew(list2, axis=0, bias=True))
print('skewness of converted data: ', skew(list3, axis=0, bias=True))
# Out:
# calculate with scipy
#
# skewness of total data:  0.553352925349285
# skewness of nondemented data:  0.5385294517131776
# skewness of demented data:  0.6196020272563664
# skewness of converted data:  0.5730556708143134

# %%
print('calculate with pandas\n')
df = pd.DataFrame(list)

print('skewness of total data: ', df.skew())

df1 = pd.DataFrame(list1)
print('skewness of nondemented data: ', df1.skew())

df2 = pd.DataFrame(list2)
print('skewness of demented data: ', df2.skew())

df3 = pd.DataFrame(list3)
print('skewness of converted data: ', df3.skew())
# Out:
# calculate with pandas
#
# skewness of total data:  0    0.558958
# dtype: float64
# skewness of nondemented data:  0    0.550056
# dtype: float64
# skewness of demented data:  0    0.634573
# dtype: float64
# skewness of converted data:  0    0.644245
# dtype: float64

# %%
import numpy as np
from scipy import stats
import statsmodels.api as sm
from scipy.stats import norm, kstest
from scipy.stats import anderson

kstest = stats.kstest(list, 'norm')
print('total data Kolmogorov-Smirnov test: ', kstest)

kstest1 = stats.kstest(list1, 'norm')
print('nondemented data Kolmogorov-Smirnov test: ', kstest1)


kstest2 = stats.kstest(list2, 'norm')
print('demented data Kolmogorov-Smirnov test: ', kstest2)


kstest3 = stats.kstest(list3, 'norm')
print('converted data Kolmogorov-Smirnov test:', kstest3)


list = np.array(list)
loc, scale = norm.fit(list)
n = norm(loc=loc, scale=scale)
kstest = stats.kstest(list, n.cdf)
print('\ntotal data Kolmogorov-Smirnov test comparing with normalized data: ', kstest)

loc, scale = norm.fit(list1)
n = norm(loc=loc, scale=scale)
kstest1 = stats.kstest(list1, n.cdf)
print('nondemented data Kolmogorov-Smirnov test comparing with normalized data: ', kstest1)

loc, scale = norm.fit(list2)
n = norm(loc=loc, scale=scale)
kstest2 = stats.kstest(list2, n.cdf)
print('demented data Kolmogorov-Smirnov test comparing with normalized data: ', kstest2)

loc, scale = norm.fit(list3)
n = norm(loc=loc, scale=scale)
kstest3 = stats.kstest(list3, n.cdf)
print('converted data Kolmogorov-Smirnov test comparing with normalized data:', kstest3)

stat, pvalue = sm.stats.diagnostic.lilliefors(list, 'norm')
stat1, pvalue1 = sm.stats.diagnostic.lilliefors(list1, 'norm')
stat2, pvalue2 = sm.stats.diagnostic.lilliefors(list2, 'norm')
stat3, pvalue3 = sm.stats.diagnostic.lilliefors(list3, 'norm')
print('\ntotal data lilliefors test: ',
      'statistic =', stat, ', pvalue =', pvalue)
print('nondemented data lilliefors test: ',
      'statistic =', stat1, ', pvalue =', pvalue1)
print('demented data lilliefors test: ',
      'statistic =', stat2, ', pvalue =', pvalue2)
print('converted data lilliefors test: ',
      'statistic =', stat3, ', pvalue =', pvalue3)

jb = stats.jarque_bera(list)
print('\ntotal data jarque-bera test: ', jb)
jb1 = stats.jarque_bera(list1)
print('nondemented data jarque-bera test: ', jb1)
jb2 = stats.jarque_bera(list2)
print('demented data jarque-bera test: ', jb2)
jb3 = stats.jarque_bera(list3)
print('converted data jarque-bera test: ', jb3)

ad = anderson(list)
print('\ntotal data anderson-darling test: ', ad)
ad1 = anderson(list1)
print('nondemented anderson-darling test: ', ad1)
ad2 = anderson(list2)
print('demented anderson-darling test: ', ad2)
ad3 = anderson(list3)
print('converted anderson-darling test: ', ad3)
# Out:
# total data Kolmogorov-Smirnov test:  KstestResult(statistic=1.0, pvalue=0.0)
# nondemented data Kolmogorov-Smirnov test:  KstestResult(statistic=1.0, pvalue=0.0)
# demented data Kolmogorov-Smirnov test:  KstestResult(statistic=1.0, pvalue=0.0)
# converted data Kolmogorov-Smirnov test: KstestResult(statistic=1.0, pvalue=0.0)
#
# total data Kolmogorov-Smirnov test comparing with normalized data:  KstestResult(statistic=0.102140462922932, pvalue=0.08146255926895096)
# nondemented data Kolmogorov-Smirnov test comparing with normalized data:  KstestResult(statistic=0.11495942938682302, pvalue=0.27556555164650576)
# demented data Kolmogorov-Smirnov test comparing with normalized data:  KstestResult(statistic=0.11214863016557375, pvalue=0.3691039791564825)
# converted data Kolmogorov-Smirnov test comparing with normalized data: KstestResult(statistic=0.15775604303432694, pvalue=0.8253655416706647)
#
# total data lilliefors test:  statistic = 0.10239711913951799 , pvalue = 0.001489148701732117
# nondemented data lilliefors test:  statistic = 0.11541245179836523 , pvalue = 0.029822166594840615
# demented data lilliefors test:  statistic = 0.11249313267864014 , pvalue = 0.05947133381253311
# converted data lilliefors test:  statistic = 0.1546626409958367 , pvalue = 0.4775261485972202
#
# total data jarque-bera test:  Jarque_beraResult(statistic=7.674724033887707, pvalue=0.021550375953557133)
# nondemented data jarque-bera test:  Jarque_beraResult(statistic=3.5820318336142023, pvalue=0.16679063815409712)
# demented data jarque-bera test:  Jarque_beraResult(statistic=4.367492113081903, pvalue=0.11261886283821021)
# converted data jarque-bera test:  Jarque_beraResult(statistic=1.0189980212977223, pvalue=0.6007964960745349)
#
# total data anderson-darling test:  AndersonResult(statistic=1.3802633633048629, critical_values=array([0.562, 0.64 , 0.767, 0.895, 1.065]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
# nondemented anderson-darling test:  AndersonResult(statistic=0.8378535315230948, critical_values=array([0.548, 0.624, 0.749, 0.874, 1.039]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
# demented anderson-darling test:  AndersonResult(statistic=0.7088716182024086, critical_values=array([0.545, 0.621, 0.745, 0.869, 1.034]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))
# converted anderson-darling test:  AndersonResult(statistic=0.30680410792027146, critical_values=array([0.497, 0.566, 0.68 , 0.793, 0.943]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
from statsmodels.stats.weightstats import ztest as ztest

Z_statics, p_value = ztest(list1, list2, value=0)
print('\n Z-test between nondementeds and dementeds: ',
      'statistic =', Z_statics, ', pvalue =', p_value)
Z_statics, p_value = ztest(list1, list3, value=0)
print('\n Z-test between nondementeds and converteds: ',
      'statistic =', Z_statics, ', pvalue =', p_value)

Z_statics, p_value = ztest(list2, list3, value=0)
print('\n Z-test between dementeds and converteds: ',
      'statistic =', Z_statics, ', pvalue =', p_value)
# Out:
#  Z-test between nondementeds and dementeds:  statistic = 0.3262665556180919 , pvalue = 0.7442226896846269
#
#  Z-test between nondementeds and converteds:  statistic = 0.6815008162908869 , pvalue = 0.495554650426248
#
#  Z-test between dementeds and converteds:  statistic = 0.5285076371626505 , pvalue = 0.5971470477641763

# %%
import scipy.stats as stats

print('\nRatio of variances:',np.var(list1)/np.var(list2))
t_statics, p_value = stats.ttest_ind(list1, list2, equal_var=True)
print('t-test between nondementeds and dementeds: ',
      'statistic =', t_statics, ', pvalue =', p_value)

print('\nRatio of variances:',np.var(list1)/np.var(list3))
t_statics, p_value = stats.ttest_ind(list1, list3, equal_var=True)
print('t-test between nondementeds and converteds: ',
      'statistic =', t_statics, ', pvalue =', p_value)

print('\nRatio of variances:',np.var(list2)/np.var(list3))
t_statics, p_value = stats.ttest_ind(list2, list3, equal_var=True)
print('t-test between dementeds and converteds: ',
      'statistic =', t_statics, ', pvalue =', p_value)
# Out:
# Ratio of variances: 1.2017774604690494
# t-test between nondementeds and dementeds:  statistic = 0.3262665556180919 , pvalue = 0.7447316925624965
#
# Ratio of variances: 2.034636353805971
# t-test between nondementeds and converteds:  statistic = 0.6815008162908869 , pvalue = 0.49742929555372206
#
# Ratio of variances: 1.6930225609422396
# t-test between dementeds and converteds:  statistic = 0.5285076371626505 , pvalue = 0.598687064595912

# %%
from statsmodels.formula.api import ols


data = pd.read_excel('oasis_longitudinal_demographics_edited.xlsx',sheet_name='Total data')
mymod = ols('eTIV ~ Group', data).fit()
# performing type 2 anova test
anovatable = sm.stats.anova_lm(mymod, typ=1)
#print('ANOVA table ')
# print('----------------------')
anovatable.head(3)
# print(anovatable)
# Out:
#              df        sum_sq       mean_sq         F    PR(>F)
# Group       2.0  1.706567e+04   8532.834259  0.263489  0.768728
# Residual  147.0  4.760457e+06  32384.060542       NaN       NaN

# %%
from scipy.stats import f_oneway
f_oneway(list1, list2, list3)
# Out:
# F_onewayResult(statistic=0.2532015954571209, pvalue=0.7766492354884741)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

ax.set_title("Box Plot", fontsize=20)
ax.set

data = [list1, list2, list3]
ax.boxplot(data, labels=['nondemented', 'demented',
           'converted'], showmeans=True)

plt.xlabel("disease stage")
plt.ylabel("eTIV")

plt.show()
